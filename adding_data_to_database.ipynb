# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
    host="localhost",
    database="YOUR_DATABASE",
    user="YOUR_USER",
    password="YOUR_PASSWORD"
)

cur = conn.cursor()

# %%
with open("data\RecipeNLG100000.csv", mode="r", encoding='utf-8') as f:
    sql = """
        COPY food_metadata
        FROM STDIN
        WITH CSV HEADER
        DELIMITER ','
        QUOTE '"'
        ESCAPE '\\';
    """

    cur.copy_expert(sql, f)

conn.commit()
cur.close()
conn.close()
